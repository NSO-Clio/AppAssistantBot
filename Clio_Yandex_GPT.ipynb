# %%
# !pip install python-docx docx2txt faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: python-docx in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (1.1.2)
# Requirement already satisfied: docx2txt in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.8)
# Requirement already satisfied: faiss-cpu in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (1.9.0)
# Requirement already satisfied: sentence-transformers in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (3.1.1)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from python-docx) (4.9.3)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from python-docx) (4.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (1.25.2)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (22.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.45.1)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\roaming\python\python311\site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.24.6)
# Requirement already satisfied: Pillow in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (10.0.1)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2023.10.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2.28.1)
# Requirement already satisfied: sympy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2022.9.24)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import config
import time
import requests
import docx2txt
import re
import json
import os
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
from typing import List, Tuple, Optional
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Обработаем документацию и переведем ее в чанки

# %%
def manage_file(file_path: str, file_type='txt') -> None:
    """
    Проверяет наличие файла. Если файл существует, очищает его. 
    Если нет, создает новый файл.

    :param file_path: Путь к файлу
    :param file_type: Тип файла ('txt' или 'json')
    """
    if file_type not in ['txt', 'json']:
        raise ValueError("file_type должен быть 'txt' или 'json'.")

    if os.path.exists(file_path):
        # Файл существует, очищаем его
        with open(file_path, 'w', encoding='utf-8') as file:
            if file_type == 'json':
                # Если это JSON-файл, записываем пустой объект
                json.dump({}, file)
            # Для текстового файла просто оставляем его пустым
    else:
        # Файл не существует, создаем новый
        with open(file_path, 'w', encoding='utf-8') as file:
            if file_type == 'json':
                json.dump({}, file)  # Записываем пустой объект для JSON


def split_long_texts(input_dict: dict, max_length: int = 1024) -> dict:
    """
    Проходит по словарю и делит длинные тексты на списки из частей по количеству слов.

    :param input_dict: Исходный словарь с текстами
    :param max_length: Максимальное количество слов в одной части
    :return: Обновленный словарь
    """
    output_dict = {}

    for key, value in input_dict.items():
        if isinstance(value, str) and len(value.split()) > max_length:
            # Разделяем текст на слова
            words = value.split()
            parts = []

            # Разбиваем слова на части по max_length
            for i in range(0, len(words), max_length):
                parts.append(" ".join(words[i:i + max_length]))

            output_dict[key] = parts
        else:
            # Если текст не длинный, оставляем его как есть
            output_dict[key] = value

    return output_dict


manage_file(r'documentation/data.txt', 'txt')
manage_file('output.json', 'json') 
print("Файлы обработаны.")
# Out:
# Файлы обработаны.

# %%
manage_file(r'documentation/data.txt', 'txt')
manage_file('output.json', 'json') 
print("Файлы обработаны.")

text = docx2txt.process(r'documentation/data.docx')
text = re.sub(r"[^А-Яа-яёЁa-zA-Z\s.,«»0-9()@._+-]", "", text)
text = re.sub(r"\(Рисунок (\d+)\)", r"[img_data/imgs\1.jpg]", text)
with open(r"documentation/data.txt", "w", encoding="utf-8") as file:
    file.write(text)

with open(r'documentation/data.txt', 'r', encoding='utf-8') as file:
    content = file.readlines()
data_plugs = {}
data_titelse = {}
fin_ind = 0
for ind, i in enumerate(content[content.index('СОДЕРЖАНИЕ\n') + 1:]):
    if len(data_plugs):
        if list(data_plugs.keys())[0] in re.sub(r'\s+', ' ', re.sub(r'[^А-Яа-яёЁa-zA-Z\s.,«»]', '', i)).strip():
            fin_ind = ind
            break
    if '.' not in i and len(re.sub(r'\s+', ' ', re.sub(r'[^А-Яа-яёЁa-zA-Z\s.,«»]', '', i)).strip()) > 0:
        data_plugs[re.sub(r'\s+', ' ', re.sub(r'[^А-Яа-яёЁa-zA-Z\s.,«»]', '', i)).strip()] = ''
    if len(re.sub(r'\s+', ' ', re.sub(r'[^А-Яа-яёЁa-zA-Z\s.,«»]', '', i)).strip()) > 0:
        data_titelse[re.sub(r'[\d\.]+|\t', '', i).strip()] = i.split('\t')[0]
point_key, ind_key = 0, 0
keys_data_plugs = list(data_plugs.keys())
for ind, i in enumerate(content[fin_ind + content.index('СОДЕРЖАНИЕ\n') + 1:]):
    if len(keys_data_plugs) <= point_key + 1:
        ind_key = ind
        break
    if keys_data_plugs[point_key + 1] not in i:
        if re.sub(r'[\d\.]+|\t', '', i).strip() in data_titelse:
            elem = i.replace(re.sub(r'[\d\.]+|\t', '', i).strip(), data_titelse[re.sub(r'[\d\.]+|\t', '', i).strip()])
            data_plugs[keys_data_plugs[point_key]] += elem
        else:
            data_plugs[keys_data_plugs[point_key]] += i
    else:
        point_key += 1
for ind, i in enumerate(content[fin_ind + content.index('СОДЕРЖАНИЕ\n') + 1 + ind_key:]):
    if re.sub(r'[\d\.]+|\t', '', i).strip() in data_titelse:
            elem = i.replace(re.sub(r'[\d\.]+|\t', '', i).strip(), data_titelse[re.sub(r'[\d\.]+|\t', '', i).strip()])
            data_plugs[keys_data_plugs[-1]] += elem
    else:
        data_plugs[keys_data_plugs[-1]] += i
with open('output.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_plugs, json_file, ensure_ascii=False, indent=4)
# Out:
# Файлы обработаны.

# %%
data_plugs
# Out:
# {'Аннотация': 'Аннотация\n\nНастоящее руководство пользователя распространяется на систему управления безопасностью конфигураций ПО (далее  КК), предназначенную для проведения аудита конфигураций встроенного, системного и прикладного программного обеспечения на соответствие лучшим практикам, внутренним стандартам и требованиям регуляторов, а также для решения задачи приведения конфигураций встроенного, системного и прикладного программного обеспечения в соответствие требуемым стандартам.\n\nВ данном руководстве приведена информация для эксплуатации системы и описание ее функциональных возможностей.\n\nДокумент предназначен для всех пользователей системы.\n\n',
#  'О системе': '\n1.1 Наименование и обозначение системы\n\nПолное наименование Система управления безопасностью конфигураций ПО.\n\nКраткое наименование ПО «КК».\n\n1.2 Область применения системы\n\nПО «КК» применяется в информационной безопасности. \n\n1.3 Основные функции системы\n\nПО «КК» обеспечивает следующие функции\n\nформирование и использование шаблонов безопасной конфигурации\n\nуправление профилями проверок конфигураций с возможностью работы с требованиями безопасности\n\nуправление базой ресурсов и программной топологией (экземплярами ПО)\n\nуправление двухуровневой иерархией моделей ПО\n\nпроведение аудита конфигураций ПО\n\nформирование отчетов и протоколов проверки по результатам аудита ПО.\n\n1.4 Роли пользователей\n\nПО «КК» предусматривает следующие роли пользователей\n\n«Пользователь»\n\n«Администратор».\n\nФункции пользователя с ролью «Администратор» описаны в документе «Руководство администратора».\n\n',
#  'Работа в системе': '\n2.1 Запуск системы\n\nПО «КК» представляет собой веб-интерфейс, запуск которого осуществляется из браузера.\n\nДля запуска ПО «КК»\n\nОткройте браузер.\n\nВведите в адресную строку адрес, по которому находится ПО.\n\nЕсли соединение было успешно установлено, то откроется страница авторизации [img_data/imgs1.jpg].\n\n2.2 Авторизация\n\nАвторизация в ПО «КК» осуществляется по логину и паролю  для авторизации введите их в соответствующие поля [img_data/imgs1.jpg].\n\n\n\nРисунок 1. Страница авторизации\n\nЕсли вход в платформу был выполнен успешно, откроется главная страница. \n\nВ целях безопасности в ПО предусмотрена смена пароля при истечении его срока действия. \n\n2.3 Просмотр информации о системе\n\nДля просмотра информации о системе требуется выбрать пункт «О продукте» в меню на странице системы.\n\nСтраница «О продукте» содержит следующее\n\nназначение и функции системы\n\nверсия системы\n\nссылка на сайт производителя\n\nссылка на сайт с документацией на систему\n\nссылка на страницу с историей версий системы\n\nссылка на лицензионное соглашение\n\nинформация о лицензии на систему.\n\n2.4 Настройка шлюзов автоматизации\n\nШлюз автоматизации предназначен для выполнения удаленного автоматического сбора и анализа конфигураций.\n\nСистема содержит следующую информацию о шлюзах автоматизации [img_data/imgs2.jpg]\n\nнаименование шлюза\n\nверсия ПО\n\nколичество потоков\n\nресурсы\n\nзадачи\n\nдата изменения статуса\n\nстатус\n\nсостояние.\n\n\n\nРисунок 2. Шлюзы автоматизации\n\nС шаблонами можно осуществлять следующие действия\n\nменять состояние\n\nудалять\n\nДля просмотра и настройки шлюзов автоматизации требуется выбрать пункт «Администрирование»  «Шлюзы автоматизации» в меню на странице системы.\n\n2.4.1 Добавление шлюза\n\nШлюз автоматизации добавляется автоматически при его обнаружении системой.\n\n2.4.2 Статусы шлюза\n\nШлюз автоматизации может иметь следующие статусы\n\n«Онлайн», если есть связь со шлюзом\n\n«Оффлайн», если нет связи со шлюзом.\n\nСмена статуса шлюза выполняется автоматически при установке или потере связи с ним.\n\n2.4.3 Состояния шлюза\n\nШлюз автоматизации может иметь следующие состояния\n\n«Активирован», если шлюз можно назначать ресурсам\n\n«Деактивирован», если шлюз нельзя назначать ресурсам.\n\nДля активации шлюза\n\nНажмите кнопку «Активировать» в строке шлюза.\n\nУбедитесь, что состояние шлюза стало «Активирован».\n\nПри деактивации шлюза обслуживание его ресурсов будет прекращено. Для деактивации шлюза\n\nНажмите кнопку «Деактивировать» в строке шлюза.\n\nПодтвердите деактивацию во всплывшем окне.\n\nУбедитесь, что состояние шлюза стало «Деактивирован».\n\n2.4.4 Удаление шлюза\n\nПеред удалением шлюза убедитесь, что он в статусе «Оффлайн» и состоянии «Деактивирован».\n\nДля удаления шлюза\n\nНажмите отмеченную кнопку [img_data/imgs3.jpg] в строке шлюза, который необходимо удалить.\n\n\n\nРисунок 3. Удаление шлюза автоматизации\n\nПодтвердите удаление во всплывшем окне.\n\nУбедитесь, что шлюз исчез из списка шлюзов.\n\n2.5 Управление учетными записями\n\nУправление учетными записями (далее  УЗ) позволяет использовать их для доступа к ресурсам.\n\nСистема содержит следующую информацию об УЗ\n\nнаименование\n\nлогин\n\nпароль\n\nотметка об использовании.\n\nОтметка об использовании показывает, используется ли УЗ в каком-либо ресурсе.\n\nС УЗ можно осуществлять следующие действия\n\nсоздавать\n\nредактировать\n\nудалять.\n\nДля управления УЗ требуется выбрать пункт «Администрирование»  «Учетные записи ПО» в меню на странице системы.\n\n2.5.1 Создание УЗ\n\nДля создания УЗ\n\nНажмите кнопку «+ Создать» и дождитесь появления окна создания УЗ.\n\nВведите наименование УЗ.\n\nВведите логин УЗ.\n\nВведите пароль УЗ.\n\nНажмите кнопку «Сохранить».\n\nУбедитесь, что созданная УЗ появилась в списке УЗ.\n\n2.5.2 Редактирование УЗ\n\nДля редактирования данных в УЗ\n\nНажмите на УЗ, которую требуется отредактировать, в списке УЗ.\n\nНажмите отмеченную кнопку [img_data/imgs4.jpg] в ка ...
#  'Дополнительная информация': '\n3.1 Сообщения об ошибках\n\nТаблица 3. Сообщения об ошибках\n\nСообщение\n\nРешение\n\nВеб-интерфейс отобразил уведомление «Could not validate credentials»\n\nТребуется ввести валидный логин и пароль\n\nВеб-интерфейс отобразил уведомление «Ошибка обновления шаблона»\n\nТребуется заново загрузить файл шаблона\n\nВеб-интерфейс отобразил уведомление «Учетная запись «Наименование УЗ» используется»\n\nТребуется удалить ресурс, в котором используется УЗ\n\nВеб-интерфейс отобразил уведомление «Выбранный элемент уже используется в данном требовании»\n\nТребуется добавить другую модель ПО в применимость профиля, либо сохранить \n\nВеб-интерфейс отобразил уведомление «Выберите хотя бы один профиль»\n\nТребуется выбрать профиль для области аудита\n\nВеб-интерфейс отобразил уведомление «Выберите хотя бы один ресурс»\n\nТребуется выбрать ресурс для области аудита\n\n\n\n\n\n\nКОНТАКТНАЯ ИНФОРМАЦИЯ\n\nТехническая поддержка\n\n+7 (495) 258-06-36\n\ninfo@lense.ru\n\nlense.ru\n\n\n\nЕсли Вам требуется квалифицированная помощь, позвоните на телефон «горячей линии поддержки», напишите письмо или воспользуйтесь формой регистрации заявки на сайте.\n\n\n\n56'}

# %%
with open('output.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_plugs, json_file, ensure_ascii=False, indent=4)

# %% [markdown]
# # Сделаем класс с подключениме YandexGPT и так же сделаме класс которыйх работает с текстом и оформляет промпт

# %%
class PromptGenerator:
    def __init__(self, chunks: List[str], qna: List[Tuple[str, str]]) -> None:
        """
        Инициализация класса PromptGenerator.

        Параметры:
        - chunks: Список текстовых фрагментов (пунктов) из нормативных документов.
        - qna: Список вопросов и ответов в формате [(вопрос, ответ)].
        """
        try:
            self.model = SentenceTransformer('BAAI/bge-m3', device="cuda")
        except:
            self.model = SentenceTransformer('BAAI/bge-m3', device="cpu")

        # Создание эмбеддингов для нормативных документов
        self.chunks = chunks
        self.embeddings = self.model.encode(self.chunks)

        # Инициализация индекса FAISS для поиска по нормативным документам
        self.index = faiss.IndexFlatL2(self.embeddings.shape[1])
        self.index.add(self.embeddings)

        # Инициализация вопросов и ответов
        self.questions, self.answers = [x[0] for x in qna], [x[1] for x in qna]
        self.qna_embeddings = self.model.encode(self.questions)
        self.qna_index = None
        if self.qna_embeddings.shape[0]:
            self.qna_index = faiss.IndexFlatL2(self.qna_embeddings.shape[1])
            self.qna_index.add(self.qna_embeddings)

    def get_embedding(self, text: str) -> np.ndarray:
        """
        Получение эмбеддинга для заданного текста.

        Параметры:
        - text: Текст для преобразования в эмбеддинг.

        Возвращает:
        - numpy.ndarray: Эмбеддинг текста.
        """
        return self.model.encode([text])[0]

    def get_similar_qna(self, question: str, k: int = 3) -> Optional[List[Tuple[str, str]]]:
        """
        Поиск похожих вопросов и ответов.

        Параметры:
        - question: Вопрос для поиска похожих.
        - k: Количество возвращаемых похожих вопросов и ответов.

        Возвращает:
        - Список из k похожих вопросов и ответов или None, если база данных пуста.
        """
        if self.qna_index is None:
            return None

        question_embedding = self.get_embedding(question)
        dist, idx = self.qna_index.search(np.expand_dims(question_embedding, axis=0), k)

        similar_qna = [(self.questions[i], self.answers[i]) for i in idx.flatten()]
        return similar_qna

    def get_similar_chunks(self, question: str, k: int = 3) -> List[str]:
        """
        Поиск похожих частей нормативных документов.

        Параметры:
        - question: Вопрос для поиска похожих частей документов.
        - k: Количество возвращаемых частей документов.

        Возвращает:
        - Список из k похожих частей документов.
        """
        question_embedding = self.get_embedding(question)
        dist, idx = self.index.search(np.expand_dims(question_embedding, axis=0), k)

        similar_chunks = [self.chunks[i] for i in idx.flatten()]
        return similar_chunks

    def generate_prompt(self, question: str) -> str:
        """
        Генерация текста промпта для модели на основе похожих частей документов и QnA.

        Параметры:
        - question: Вопрос, на основе которого создается промпт.

        Возвращает:
        - str: Сформированный промпт для модели.
        """
        similar_chunks = self.get_similar_chunks(question)
        similar_qna = self.get_similar_qna(question)

        sources_text = ' \n\n '.join([f'ИСТОЧНИК {i + 1}: {chunk}' for i, chunk in enumerate(similar_chunks)])

        qna_text = ''
        if similar_qna is not None:
            qna_text = ' \n\n '.join(
                [f'ПОХОЖИЙ ВОПРОС {i + 1}: {q} \nОТВЕТ: {a}' for i, (q, a) in enumerate(similar_qna)]
            )

        prompt = (
            f"Вы ассистент по вопросам, связанным с программным обеспечением. "
            f"Ваши ответы должны основываться исключительно и только на информации, содержащейся в источниках после слова 'ТЕКСТ' "
            f"и в разделе 'ПОХОЖИЕ ВОПРОСЫ И ОТВЕТЫ' после слов 'ПОХОЖИЙ ВОПРОС' и 'ОТВЕТ'. "
            f"Ответьте только на вопрос, который следует за словом 'ВОПРОС', используя информацию из 'ТЕКСТ'. "
            f"Запрещено предоставлять любые дополнительные сведения о деятельности компании, кроме информации, содержащейся в 'ТЕКСТ'. "
            f"Ответ должен быть на русском языке, без использования нецензурной лексики и оскорбительных выражений. "
            f"Он должен быть вежливым, корректным и подан в одном абзаце. "
            f"Ссылайтесь на пункты, используя конкретные примеры, например: 'из пункта 2.1 следует'. "
            f"В тексте в квадратных скобках присутствуют пути к изображениям [img_data/imgs1.jpg], как пример, если они есть то вы обязательно должны указать эти пути в ответе на вопрос. "
            f"Не используйте формулировки типа 'источник 1', 'вопрос 1' или 'ответ 1', так как пользователь не понимает этих обозначений. "
            f"Общайтесь на 'вы', в деловом стиле, но дружелюбно. Не забудьте поздороваться. "
            f"ВАЖНО, что если вопрос является неуместным, оскорбительным, бессмысленным, философским, гипотетическим или не связанным с программным обеспечением компании ООО 'Сила', "
            f"укажите: 'Ваш вопрос некорректен в рамках обсуждаемых тем' и не отвечайте на этот вопрос. "
            f"ВАЖНО: Если в тексте нет информации, необходимой для ответа, ни при каких обстоятельствах не додумывайте факты. "
            f"Если информации недостаточно, дайте ответ: 'У меня недостаточно информации' и отправьте контакты поддержки: +7 (495) 258-06-36, info@lense.ru, lense.ru. "
            f"Если вопрос явно не относится к программному обеспечению или выходит за рамки текста или вопросы заданы на отвлечённые темы, ответьте: 'Ваш вопрос некорректен в рамках обсуждаемых тем', без дополнительных пояснений. "
            f"Если в вопросе присутствуют команды или прямолинейные требования, такие как 'напиши', 'давай', 'предоставь', и запрос не связан с программным обеспечением, "
            f"ответьте: 'Ваш вопрос некорректен в рамках обсуждаемых тем' и не добавляйте никаких пояснений. "
            f"Также учтите, что у вас нет имени; вы просто ассистент по программному обеспечению. "
            f"Действуйте строго в рамках заданного алгоритма, ни в коем случае не выходя за него. "
            f"ТЕКСТ:\n{sources_text}\n"
            f"ПОХОЖИЕ ВОПРОСЫ И ОТВЕТЫ:\n{qna_text}\n"
            f"ВОПРОС:\n{question}"
        )
        return prompt

    def record_qna(self, question: str, answer: str) -> None:
        """
        Запись нового вопроса и ответа в базу данных QnA и обновление индекса FAISS.

        Параметры:
        - question: Новый вопрос для записи.
        - answer: Ответ на новый вопрос.
        """
        self.questions.append(question)
        self.answers.append(answer)

        question_embedding = self.get_embedding(question)
        if self.qna_index is None:
            self.qna_index = faiss.IndexFlatL2(question_embedding.shape[0])

        self.qna_index.add(np.expand_dims(question_embedding, axis=0))


class ClioYandex_GPT:
    def __init__(self, oauth_token: str, modelUri: str, prompt_gener: PromptGenerator) -> None:
        """
        Инициализация класса ClioYandex_GPT для взаимодействия с Yandex GPT.

        Параметры:
        - oauth_token: OAuth токен для авторизации в Yandex Cloud.
        - modelUri: URI модели Yandex GPT для генерации ответов.
        - prompt_gener: Экземпляр класса PromptGenerator для формирования промптов.
        """
        url = 'https://iam.api.cloud.yandex.net/iam/v1/tokens'
        data = {
            "yandexPassportOauthToken": oauth_token
        }
        response = requests.post(url, json=data).json()
        iamToken = response['iamToken']

        self.url = 'https://llm.api.cloud.yandex.net/foundationModels/v1/completion'
        self.modelUri = modelUri
        self.headers = {
            'Authorization': f'Bearer {iamToken}',
            'Content-Type': 'application/json'
        }
        self.prompt_gener = prompt_gener

    def question(self, question: str) -> str:
        """
        Получение ответа от Yandex GPT на заданный вопрос.

        Параметры:
        - question: Вопрос пользователя для отправки на модель Yandex GPT.

        Возвращает:
        - str: Ответ, сгенерированный моделью Yandex GPT.
        """
        data = {
            "modelUri": self.modelUri,
            "completionOptions": {
                "stream": False,
                "temperature": 0.6,
                "maxTokens": 2000
            },
            "messages": [
                {
                    "role": "user",
                    "text": self.prompt_gener.generate_prompt(question)
                }
            ]
        }
        response = requests.post(
            self.url, headers=self.headers, json=data
        ).json()
        # print(response)
        return response['result']['alternatives'][0]['message']['text']

# %% [markdown]
# # Протестируем это все

# %%
chunks = []
chunks_data = split_long_texts(data_plugs, max_length=512)
for i in chunks_data:
    if type(chunks_data[i]) != list:
        chunks.append(data_plugs[i])
    else:
        for elem in chunks_data[i]:
            chunks.append(elem)

# %%
prompt_gen = PromptGenerator(
    chunks=chunks,
    qna=[]
)

# %%
model = ClioYandex_GPT(
    oauth_token=config.YANDEX_PASSPORT_O_AUTH_TOKEN,
    modelUri=config.MODEL_URI,
    prompt_gener=prompt_gen
)

# %%
questions = [
    "С чего начать работу?",
    "Какой первый шаг?",
    "Как провести аудит?",
    "Что такое «Профиль»?",
    "Как создать профиль?",
    "Как создать требование?",
    "Что такое применимость профиля? Применимость требования? Могут ли применимости не совпадать?",
    "Как создать ресурс? Где взять IP-адрес ресурса?",
    "Зачем нужен ресурс оффлайн?",
    "Не создается ресурс, что делать?",
    "Как включить шлюз?",
    "В области аудита не виден профиль, почему?",
    "Почему не отображается ресурс при создании области аудита?",
    "Почему в требовании во вкладке «Сбор конфигурации» не отображается созданный ресурс?",
    "Что такое «Шаблон»?",
    "Выполнен аудит, почему статус протокола остался «В работе»?",
    "Модели ПО для чего нужны? Кто их создает?",
    "Как работать с Моделью ПО?",
    "Модели ПО и их связь с программной топологией ресурса",
    "Учетные записи ПО и их связь с программной топологией ресурса",
    "Закончилась лицензия КК – как продлить?",
    "Можно ли редактировать профиль «Активный»?",
    "Можно ли редактировать профиль «Архивный»?",
    "Можно ли создать копию профиля?",
    "Можно ли выгрузить скрипты выполненного протокола?",
    "Сколько максимально можно создать ресурсов?",
    "Сколько максимально можно создать профилей?",
    "Сколько максимально можно создать требований в профиле?",
    "Возможные ошибки при аудите?",
    "Статусы проверок в протоколе: «соответствует», «не соответствует», «в работе», «не применимо»",
    "Создано 2 блока применимости требования, выбираю требование, в нем не отображаются заполненные поля скрипта, почему?",
    "Не могу удалить профиль, почему?",
    "Можно ли создать свой шаблон и выгрузить его?",
    "Где ознакомиться с документацией на КК?",
    "Откуда берется балл протокола? Как считается?",
    "Типы ошибок в КК",
    "Авторизация: не получается авторизоваться, что делать? Пароль не подходит"
]

# %%
i = 0
data_quastions = []
while i < len(questions):
    q = questions[i]
    try:
        ans = model.question(question=q)
        print(q, ans, sep='\n')
        print('----------------------------------')
        i += 1
        data_quastions.append([q, ans])
        time.sleep(16) # Чтобы не было блокировок по API Yandex, для сбора данных
    except:
        print("Ошибка")
with open('data_quastions.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_quastions, json_file, ensure_ascii=False, indent=4)
# Out:
# С чего начать работу?
# Здравствуйте!
#
# Для начала работы с программным обеспечением ООО «Сила» вам необходимо ознакомиться с документацией и инструкциями. Вы можете найти их на нашем сайте или обратиться к нашим специалистам за помощью.
#
# Если у вас возникнут вопросы по работе с ПО, вы всегда можете обратиться в службу поддержки: +7 (495) 258-06-36, info@lense.ru, lense.ru.
# ----------------------------------
# Какой первый шаг?
# Здравствуйте!
#
# Первым шагом обычно является изучение документации и инструкций по использованию программного обеспечения. В зависимости от конкретного продукта, это может включать в себя установку программы, авторизацию или регистрацию в системе, а также ознакомление с основными функциями и возможностями.
#
# В случае возникновения дополнительных вопросов или проблем в процессе работы, рекомендуется обратиться к поддержке или службе технической помощи для получения дополнительной информации и помощи.
# ----------------------------------
# Как провести аудит?
# Здравствуйте!
#
# Чтобы провести аудит, нужно создать область аудита. Это можно сделать двумя способами: на базе профилей или на базе ресурсов.
#
# 1. Чтобы создать область аудита на базе профилей, нажмите кнопку «+» над списком областей и дождитесь всплытия окна создания области. Введите наименование области аудита, отметьте пункт «Профилей», затем — профили в списке профилей. Отметьте ресурсы в списке ресурсов, применимые к выбранным профилям, и нажмите кнопку «Сохранить».
# 2. Чтобы создать область аудита на базе ресурсов, также нажмите кнопку «+» над списком областей. Введите наименование области аудита, отметьте пункт «Ресурсов», затем — ресурсы в списке ресурсов. Отметьте профили, которые применимы к выбранным ресурсам, и также нажмите кнопку «Сохранить».
# ----------------------------------
# Что такое «Профиль»?
# Профиль — это набор требований, который применяется к определённой модели программного обеспечения (ПО). С помощью профилей можно проверять безопасность конфигурации компонентов.
# ----------------------------------
# Как создать профиль?
# Здравствуйте!
#
# Чтобы создать профиль, нажмите кнопку «+ Профиль» справа над списком профилей. Дождитесь всплытия окна создания профиля. Введите уникальное наименование профиля и нажмите «Сохранить». Убедитесь, что созданный профиль появился в списке профилей.
# ----------------------------------
# Как создать требование?
# Для создания требования вне раздела нажмите кнопку «+» над списком требований. Нажмите отмеченную кнопку в правом верхнем углу созданного требования. Заполните данные созданного требования (см. п. 2.9.6, 2.9.7, 2.9.8, 2.9.9 и 2.9.10). Нажмите кнопку «Сохранить».
#
# Для создания требования внутри раздела нажмите правой кнопкой мыши на раздел, в котором требуется создать требование. Нажмите кнопку «Создать требование» в контекстном меню. Нажмите отмеченную кнопку [img_data/imgs30.jpg] в правом верхнем углу созданного требования. Заполните данные созданного требования (см. п. 2.9.6, 2.9.7, 2.9.8, 2.9.9 и 2.9.10). Нажмите кнопку «Сохранить».
# ----------------------------------
# Что такое применимость профиля? Применимость требования? Могут ли применимости не совпадать?
# Применимость профиля — это свойство, которое определяет, к каким моделям программного обеспечения (ПО) может быть применён профиль.
#
# Применимость требования — это возможность использования требования в определённых моделях ПО.
#
# Да, применимости могут не совпадать.
# ----------------------------------
# Как создать ресурс? Где взять IP-адрес ресурса?
# Здравствуйте! Для создания online-ресурса через контекстное меню раздела нажмите правой кнопкой мыши на раздел, в котором требуется создать ресурс. Нажмите кнопку «Создать ресурс» в контекстном меню. Дождитесь всплытия окна создания ресурса. Введите наименование ресурса. Включите работу с ресурсом по сети переключателем «Работать с ресурсом по сети». Введите IP-адрес ресурса. Выберите шлюз автоматизации из перечня шлюзов. Нажмите кнопку «Сохранить».
#
# Для создания offline-ресурса нажмите отмеченную кнопку «+» над списком ресурсов. Дождитесь появления окна создания ресурса. Введите наименование ресурса. Отключите работу с ресурсом по сети. Нажмите кнопку «Сохранить».
# ----------------------------------
# Зачем нужен ресурс оффлайн?
# Здравствуйте!
#
# Ресурс без сетевого доступа (offline-ресурс) нужен для работы в режиме отсутствия подключения к сети. Это позволяет выполнять определённые задачи, когда доступ к интернету ограничен или недоступен.
# ----------------------------------
# Не создается ресурс, что делать?
# Здравствуйте!
#
# Для создания ресурса попробуйте выполнить следующие шаги:
# 1. Нажмите на кнопку «+» над списком ресурсов или используйте контекстное меню раздела.
# 2. Дождитесь всплытия окна создания ресурса и введите его наименование.
# 3. Включите работу с ресурсом по сети, если это необходимо.
# 4. Введите IP-адрес ресурса.
# 5. Выберите шлюз автоматизации из перечня шлюзов.
# 6. Нажмите кнопку «Сохранить».
#
# Если после выполнения этих действий ресурс не создастся, обратитесь в службу поддержки ООО «Сила» по телефону +7 (495) 258-06-36, электронной почте info@lense.ru или через веб-сайт lense.ru.
# ----------------------------------
# Как включить шлюз?
# Для включения шлюза автоматизации необходимо выполнить следующие шаги:
# 1. Перейдите в систему управления ПО «КК».
# 2. Выберите пункт «Администрирование» → «Шлюзы автоматизации».
# 3. Нажмите кнопку «Активировать» в строке нужного шлюза.
#
# Убедитесь, что состояние шлюза стало «Активирован».
# ----------------------------------
# В области аудита не виден профиль, почему?
# Здравствуйте!
#
# Чтобы увидеть профиль в области аудита, нажмите отмеченную кнопку [img_data/imgs46.jpg] справа в строке с наименованием области аудита, которую требуется отредактировать. Нажмите кнопку «Редактировать». Отметьте ресурсы, которые требуется добавить в область. Удалите отметки с ресурсов, которые требуется удалить из области. Затем нажмите кнопку «Сохранить».
#
# Если у вас остались вопросы или появились дополнительные, напишите их мне. Я постараюсь помочь вам разобраться в ситуации.
# ----------------------------------
# Почему не отображается ресурс при создании области аудита?
# Здравствуйте!
#
# Для решения проблемы проверьте следующее:
# * ресурс действительно существует в системе;
# * вы создали область аудита на базе ресурсов, нажав кнопку «+» над списком областей и выбрав пункт «Ресурсов»;
# * вы отметили необходимые ресурсы в списке.
#
# Если после проверки ситуация не изменится, пожалуйста, сообщите об этом в службу поддержки компании ООО «Сила»: +7 (495) 258-06-36, info@lense.ru, lense.ru.
# ----------------------------------
# Почему в требовании во вкладке «Сбор конфигурации» не отображается созданный ресурс?
# Здравствуйте! Для того чтобы в требовании во вкладке «Сбор конфигурации» отобразился созданный ресурс, необходимо выполнить следующие действия:
#
# 1. Создать ресурс (см. п. 2.10).
# 2. Выбрать этот ресурс из перечня ресурсов.
# 3. Убедиться, что ресурс отображается во вкладке «Сбор конфигурации».
#
# Если после выполнения этих действий ресурс всё ещё не отображается, возможно, возникла техническая ошибка. В таком случае рекомендуется обратиться в службу поддержки для получения дополнительной помощи.
# ----------------------------------
# Что такое «Шаблон»?
# **Шаблон** — это набор рекомендуемых требований безопасности к модели программного обеспечения (ПО). Шаблоны являются основой профилей проверок, которые создают пользователи. Они предоставляются разработчиками системы в файлах в формате LNZ.
#
# После загрузки шаблона его модель появится в иерархии моделей ПО. Система содержит следующую информацию о шаблонах: наименование, номер версии, дата последнего обновления версии и применимость.
# ----------------------------------
# Выполнен аудит, почему статус протокола остался «В работе»?
# Здравствуйте!
#
# Чтобы разобраться, почему статус протокола остался «В работе», необходимо уточнить дополнительную информацию. Пожалуйста, проверьте, завершены ли все проверки аудита и выполнены ли необходимые ручные действия для требований с отметками «требуется завершить сбор конфигурации» и «требуется завершить анализ конфигурации».
#
# Если у вас остались вопросы или нужна дополнительная помощь, пожалуйста, свяжитесь с нашей службой поддержки по телефону +7 (495) 258-06-36 или электронной почте info@lense.ru.
# ----------------------------------
# Модели ПО для чего нужны? Кто их создает?
# Модели ПО — это основа иерархии программного обеспечения, которая представляет собой древовидную структуру. Иерархия моделей ПО нужна для назначения применимости профилям и требованиям.
#
# Модели ПО создают двумя способами:
# 1. Загрузка шаблона (см. п. 2.7.2).
# 2. Создание модели через кнопку на странице моделей или контекстное меню раздела (см. пункты 2.6.1–2.6.3).
# ----------------------------------
# Как работать с Моделью ПО?
# Модель ПО — это древовидная структура моделей ПО, предназначенная для назначения применимости профилям и требованиям.
#
# С моделями ПО можно осуществлять следующие действия: создавать, редактировать, удалять, устанавливать связь с ними.
#
# Для управления моделями ПО требуется выбрать пункт «Администрирование» — «Модели ПО» в меню на странице системы.
# ----------------------------------
# Модели ПО и их связь с программной топологией ресурса
# Здравствуйте!
#
# Модели программного обеспечения (ПО) — это компоненты, которые функционируют на программной топологии ресурса. Программная топология ресурса — это набор экземпляров ПО, установленных на ресурсе. Экземпляры ПО соответствуют конкретным моделям ПО из иерархии.
#
# В программной топологии могут быть экземпляры ПО уровней 1 и 2 в соответствии с иерархией моделей ПО. Для добавления экземпляров ПО в программную топологию необходимо выбрать ресурс в списке ресурсов, нажать отмеченную кнопку и дождаться появления окна редактирования программной топологии. Затем можно добавить один или несколько экземпляров ПО уровня 1 или 2.
# ----------------------------------
# Учетные записи ПО и их связь с программной топологией ресурса
# Здравствуйте!
#
# В программной топологии ресурса экземплярам ПО любого уровня можно менять параметры подключения: указывать тип учётной записи, тип взаимодействия и номер порта.
#
# Для редактирования параметров подключения экземпляров ПО необходимо выбрать ресурс в списке ресурсов, нажать отмеченную кнопку и дождаться появления окна редактирования программной топологии. После этого нужно нажать на экземпляр ПО, который требуется отредактировать, и выбрать тип учётной записи (локальная или глобальная).
#
# Если выбрана локальная учётная запись, потребуется ввести логин и пароль. Если выбрана глобальная учётная запись — выбрать её из выпадающего списка. Затем следует указать тип взаимодействия и ввести номер порта, после чего нажать кнопку «Сохранить».
# ----------------------------------
# Закончилась лицензия КК – как продлить?
# Здравствуйте!
#
# Для продления лицензии обратитесь к руководству администратора.
# ----------------------------------
# Можно ли редактировать профиль «Активный»?
# Здравствуйте! Да, профиль «Активный» можно редактировать. Для этого нажмите на наименование профиля, который требуется отредактировать, в списке профилей. Управление требованиями описано в п. 2.9.
# ----------------------------------
# Можно ли редактировать профиль «Архивный»?
# Здравствуйте!
#
# Профиль со статусом «Архивный» нельзя отредактировать.
#
# Однако, если профиль был ранее активирован, то изменить его статус на «Архивный», можно двумя способами: через список профилей или карточку профиля.
# ----------------------------------
# Можно ли создать копию профиля?
# Да, можно создать копию профиля двумя способами: через список профилей или через карточку профиля.
# ----------------------------------
# Можно ли выгрузить скрипты выполненного протокола?
# Здравствуйте! Для того, чтобы выгрузить скрипты выполненного протокола аудита, необходимо завершить сбор и анализ конфигурации. Это можно сделать в карточке задачи из области аудита на странице «Аудиты».
#
# После завершения сбора и анализа конфигурации появится возможность скачать протокол аудита, который будет содержать скрипты выполненных действий.
# ----------------------------------
# Сколько максимально можно создать ресурсов?
# Здравствуйте! Спасибо за вопрос. Максимальное количество ресурсов, которое можно создать, зависит от настроек системы и её возможностей. В системе содержится вся информация о ресурсах, включая их наименование, IP-адрес, список экземпляров ПО и другую информацию. Для создания ресурса необходимо выбрать пункт «Ресурсы» в меню на странице системы.
# ----------------------------------
# Сколько максимально можно создать профилей?
# Здравствуйте!
#
# Максимальное количество профилей, которые можно создать, не ограничено.
# ----------------------------------
# Сколько максимально можно создать требований в профиле?
# В профиле можно создать любое количество требований.
# ----------------------------------
# Возможные ошибки при аудите?
# Здравствуйте!
#
# В процессе аудита могут возникнуть различные ошибки. Для получения более подробной информации о возможных ошибках при аудите, пожалуйста, обратитесь к разделу «Сообщения об ошибках» в ИСТОЧНИКЕ 2.
# ----------------------------------
# Статусы проверок в протоколе: «соответствует», «не соответствует», «в работе», «не применимо»
# Здравствуйте!
#
# В протоколе аудита действительно могут быть указаны статусы «соответствует», «не соответствует», «в работе», «не применимо». Они обозначают состояние выполнения требований.
#
# * Статус **«в работе»** означает, что в протоколе есть требования, требующие ручного действия.
# * Статус **«завершён»** означает, что все проверки завершены.
# * **Соответствующие** требования выполнены.
# * Если требование **не соответствует**, это значит, что оно не выполнено.
# * **«Не применимо»** означает, что требование не может быть применено к текущему профилю или экземпляру ПО.
# ----------------------------------
# Создано 2 блока применимости требования, выбираю требование, в нем не отображаются заполненные поля скрипта, почему?
# Здравствуйте!
#
# Для корректной работы системы необходимо проверить правильность настройки скрипта и его отображения в карточке требования. Возможно, потребуется обновить страницу или перезагрузить систему.
#
# Если проблема не устраняется, рекомендуется обратиться в службу поддержки для получения дополнительной помощи.
# ----------------------------------
# Не могу удалить профиль, почему?
# Здравствуйте!
#
# Профиль нельзя удалить, если в нём есть требования. Для удаления профиля необходимо перейти в режим редактирования карточки профиля и удалить все требования из профиля. После этого профиль можно будет удалить.
# ----------------------------------
# Можно ли создать свой шаблон и выгрузить его?
# Здравствуйте! Да, можно создать свой шаблон и выгрузить его. Для создания шаблона нажмите на профиль, на основе которого требуется создать шаблон, в списке профилей. Нажмите отмеченную кнопку [img_data/imgs14.jpg] в строке с названием профиля и дождитесь появления окна создания шаблона (Рисунок 14). Введите наименование шаблона. Нажмите кнопку «Сохранить». Перейдите на страницу «Шаблоны» и убедитесь, что шаблон появился в списке шаблонов.
#
# Для выгрузки шаблона нажмите на профиль, шаблон которого требуется выгрузить, в списке профилей (Рисунок 15). Нажмите отмеченную кнопку в строке с названием профиля. Дождитесь скачивания шаблона.
# ----------------------------------
# Где ознакомиться с документацией на КК?
# С документацией на КК можно ознакомиться на странице «О продукте», которая открывается после выбора соответствующего пункта в меню.
# ----------------------------------
# Откуда берется балл протокола? Как считается?
# Балл протокола аудита рассчитывается на основе результатов проверки требований. Каждый протокол содержит список требований, и каждое требование может иметь определённый статус: «соответствует», «не соответствует», «требуется завершить сбор конфигурации» или «требуется завершить анализ конфигурации».
#
# По результатам проверки каждому статусу присваивается определённое количество баллов. Сумма баллов по всем требованиям формирует общий балл протокола.
# ----------------------------------
# Типы ошибок в КК
# Здравствуйте!
#
# В системе управления безопасностью конфигураций ПО могут возникать различные ошибки. Для получения более подробной информации о возможных ошибках в работе системы рекомендуется обратиться к руководству администратора или специалисту технической поддержки.
# ----------------------------------
# Авторизация: не получается авторизоваться, что делать? Пароль не подходит
# Здравствуйте!
#
# Чтобы решить проблему с авторизацией, попробуйте выполнить следующие шаги:
# 1. Проверьте правильность введённых логина и пароля.
# 2. Убедитесь, что срок действия пароля не истёк. В этом случае вам потребуется сменить пароль.
# 3. Если у вас возникли проблемы с доступом, обратитесь в службу поддержки. Контактная информация указана на сайте компании.
# ----------------------------------

# %% [markdown]
# ### Заметим, что модель для всех вопросов выдала понятный и ясный ответ, поэтому такая метрика, как covering = answered_questions / all_questions = 1

# %%
bad_questions = [
    "Почему у кошек шесть жизней, а у собак — только одна?",
    "Какое мороженое самое вкусное по мнению моделей?",
    "Можно ли запустить ракету из кастрюли?",
    "Как мне стать космонавтом за один день?",
    "Почему нельзя съесть облако?",
    "Какой цвет лучше всего подходит для зимы?",
    "Могу ли я написать диплом на тему «Путешествия картофеля»?",
    "Сколько радуг помещается в один квадратный метр?",
    "Почему кит не летает, если он большой?",
    "Какое приложение поможет мне понимать мысли моего кота?"
]

# %%
i = 0
while i < len(bad_questions):
    q = bad_questions[i]
    try:
        ans = model.question(question=q)
        print(q, ans, sep='\n')
        print('----------------------------------')
        i += 1
        time.sleep(16) # Чтобы не было блокировок по API Yandex, для сбора данных
    except:
        print("Ошибка")
# Out:
# Почему у кошек шесть жизней, а у собак — только одна?
# Здравствуйте! Я не могу ответить на этот вопрос, поскольку он не связан с программным обеспечением компании ООО «Сила». Если у вас есть вопросы о программном обеспечении нашей компании, пожалуйста, задайте их мне.
# ----------------------------------
# Какое мороженое самое вкусное по мнению моделей?
# Здравствуйте! Я не могу ответить на этот вопрос, поскольку он не связан с программным обеспечением компании ООО «Сила». Если у вас есть вопросы по программному обеспечению, я готов помочь.
#
# Если ваш вопрос не касается программного обеспечения, вы можете обратиться к другим специалистам нашей компании или задать свой вопрос в другом месте.
#
# В случае возникновения вопросов или проблем, связанных с использованием программного обеспечения ООО «Сила», вы всегда можете связаться с нашей службой поддержки по телефону +7 (495) 258-06-36 или электронной почте info@lense.ru.
# ----------------------------------
# Можно ли запустить ракету из кастрюли?
# Здравствуйте!
#
# Программное обеспечение компании ООО «Сила» не предназначено для управления ракетами и не может использоваться в таких целях.
#
# Если у вас есть вопросы, связанные с программным обеспечением компании ООО «Сила», я готов помочь.
# ----------------------------------
# Как мне стать космонавтом за один день?
# Здравствуйте! Я не могу предоставить информацию, которая не связана с программным обеспечением компании ООО «Сила». Если у вас есть вопросы по программному обеспечению, пожалуйста, задайте их мне.
#
# Если ваш вопрос о том, как стать космонавтом, не связан с программным обеспечением, то он некорректен в рамках обсуждаемых тем. Однако я могу предложить вам обратиться к специалистам, которые могут предоставить соответствующую информацию.
# ----------------------------------
# Почему нельзя съесть облако?
# Здравствуйте!
#
# В системе, которую разрабатывает компания ООО «Сила», нет информации о том, почему нельзя съесть облако.
#
# Если у вас возникли вопросы по работе с программным обеспечением нашей компании, пожалуйста, сформулируйте их, и я постараюсь вам помочь.
# ----------------------------------
# Какой цвет лучше всего подходит для зимы?
# ОТВЕТ:
# Для зимы лучше всего подходят холодные цвета, такие как синий или фиолетовый. Однако выбор цвета зависит от личных предпочтений и стиля одежды.
# ----------------------------------
# Могу ли я написать диплом на тему «Путешествия картофеля»?
# Вы можете написать диплом на любую тему, которая вам интересна и соответствует требованиям вашего учебного заведения. Однако тема «Путешествия картофеля» может вызвать определённые сложности в поиске источников информации и структурировании работы. Если вы уверены, что сможете справиться с этими трудностями, то дерзайте!
# ----------------------------------
# Сколько радуг помещается в один квадратный метр?
# Здравствуйте! Я — ассистент по программному обеспечению. К сожалению, я не могу ответить на этот вопрос, так как он не связан с программным обеспечением компании ООО «Сила». Вы можете обратиться к специалистам в других областях или воспользоваться поисковыми системами для получения нужной информации.
# ----------------------------------
# Почему кит не летает, если он большой?
# Добрый день!
#
# Я не могу ответить на этот вопрос, так как он не связан с программным обеспечением компании ООО «Сила».
#
# Если у вас есть вопросы, связанные с программным обеспечением, я готов помочь.
# ----------------------------------
# Какое приложение поможет мне понимать мысли моего кота?
# Здравствуйте! Я — ассистент по вопросам, связанным с программным обеспечением. Компания ООО «Сила» разрабатывает программное обеспечение для аудита конфигураций встроенного, системного и прикладного программного обеспечения на соответствие лучшим практикам, внутренним стандартам и требованиям регуляторов. К сожалению, я не смогу помочь вам в понимании мыслей вашего кота.
#
# Однако, если у вас есть вопросы, связанные с программным обеспечением компании ООО «Сила», вы можете задать их мне, и я постараюсь вам помочь.
# ----------------------------------

# %% [markdown]
# ### Также заметим, что модель для большинства плохих вопросов не выдавала ответов и игнорировала их, поэтому опять же такая метрика, как covering_ignoring = ignored_questions / all_questions = 0.8
